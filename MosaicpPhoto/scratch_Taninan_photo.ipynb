# %% [markdown]
# https://github.com/ultralytics/flickr_scraper?fbclid=IwAR24AyioC562EutqUuAvkZiPuC0fc7fxB1Em3QE7Kv8iNZVKXgfCkfdsH-M

# %% [markdown]
# key = 'acd5a3f943cba23a27bf055e525a7343' # Flickr API key https://www.flickr.com/services/apps/create/apply <br />
# secret = '3a19614d9ba4e6e0' <br />

# %%
# Generated by Glenn Jocher (glenn.jocher@ultralytics.com) for https://github.com/ultralytics

import os
import time

import requests
from flickrapi import FlickrAPI

key = 'acd5a3f943cba23a27bf055e525a7343'
secret = '3a19614d9ba4e6e0'

# %%
def download_uri(uri, dir='./'):
    with open(dir + uri.split('/')[-1], 'wb') as f:
        f.write(requests.get(uri, stream=True).content)

# %%
def get_urls(search, n, download):
    t = time.time()
    flickr = FlickrAPI(key, secret)
    photos = flickr.walk(text=search,  # http://www.flickr.com/services/api/flickr.photos.search.html
                         extras='url_o',
                         per_page=100,
                         sort='relevance')

    if download:
        dir = search.replace(' ', '_') + os.sep  # save directory
        if not os.path.exists(dir):
            os.makedirs(dir)

    urls = []
    for i, photo in enumerate(photos):
        if i == n:
            break

        try:
            # construct url https://www.flickr.com/services/api/misc.urls.html
            url = photo.get('url_o')  # original size
            if url is None:
                url = 'https://farm%s.staticflickr.com/%s/%s_%s_b.jpg' % \
                      (photo.get('farm'), photo.get('server'), photo.get('id'), photo.get('secret'))  # large size

            # download
            if download:
                download_uri(url, dir)

            urls.append(url)
            print('%g/%g %s' % (i, n, url))
        except:
            print('%g/%g error...' % (i, n))

    print('Done. (%.1fs)' % (time.time() - t) + ('\nAll images saved to %s' % dir if download else ''))

# %%
if __name__ == '__main__':

    get_urls(search='Tainan',  # search term
             n=256,  # max number of images
             download=True)  # download images
